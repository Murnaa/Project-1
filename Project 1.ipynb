# %% [markdown]
# ## **Import Pandas**

# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\abunm\OneDrive\Desktop\data.csv')

# %% [markdown]
# ## **Remove Null values**

# %%
y = data.dropna()
y
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### <span style="color:black">**The Pandas .dropna() method allows the user to analyze and drop rows/columns with Null values. Pandas .dropna() method offers a lot of flexibility in how to drop records with missing values.**</span>

# %% [markdown]
# ## **Remove Duplicates**

# %%
data = y.drop_duplicates()
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ## **Statistical Inferences of the Entire Dataset**

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1591.000000  1591.000000          1591.000000           1591.000000
# mean         2.540761     0.087500            15.861722             46.498429
# std          1.413076     0.047175            10.429385             32.998659
# ...

# %% [markdown]
# ## **Statistical Inferences of Individual Columns in the Dataset**

# %%
data['ID'].describe()
# Out:
# count    1591.000000
# mean      801.060968
# std       460.740942
# min         1.000000
# 25%       402.500000
# 50%       801.000000
# 75%      1199.500000
# max      1601.000000
# Name: ID, dtype: float64

# %%
data['fixed acidity'].describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
data['volatile acidity'].describe()
# Out:
# count    1591.000000
# mean        0.527681
# std         0.179045
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
data['citric acid'].describe()
# Out:
# count    1591.000000
# mean        0.271477
# std         0.194807
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
data['residual sugar'].describe()
# Out:
# count    1591.000000
# mean        2.540761
# std         1.413076
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
data['chlorides'].describe()
# Out:
# count    1591.000000
# mean        0.087500
# std         0.047175
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
data['free sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       15.861722
# std        10.429385
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
data['total sulfur dioxide'].describe()
# Out:
# count    1591.000000
# mean       46.498429
# std        32.998659
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
data['density'].describe()
# Out:
# count    1591.000000
# mean        0.996747
# std         0.001889
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997845
# max         1.003690
# Name: density, dtype: float64

# %%
data['pH'].describe()
# Out:
# count    1591.000000
# mean        3.311358
# std         0.154548
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
data['sulphates'].describe()
# Out:
# count    1591.000000
# mean        0.658611
# std         0.169786
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
data['alcohol'].describe()
# Out:
# count    1591.000000
# mean       10.426053
# std         1.066706
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
data['quality'].describe()
# Out:
# count    1591.000000
# mean        5.637964
# std         0.807772
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
#Data Correlation Among Columns
data.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.268371         -0.006833    -0.156712
# fixed acidity        -0.268371       1.000000         -0.256737     0.672306
# volatile acidity     -0.006833      -0.256737          1.000000    -0.551511
# citric acid          -0.156712       0.672306         -0.551511     1.000000
# residual sugar       -0.031780       0.114839          0.001336     0.143731
# chlorides            -0.119930       0.093857          0.061202     0.204294
# free sulfur dioxide   0.085616      -0.150261         -0.014598    -0.057619
# total sulfur dioxide -0.115795      -0.110992          0.074132     0.038593
# density              -0.368878       0.666876          0.022504     0.364181
# pH                    0.133390      -0.683788          0.234251    -0.543230
# sulphates            -0.127397       0.184937         -0.261872     0.313530
# ...

# %% [markdown]
# #  Plotting  Data

# %% [markdown]
# ### **Hidden Inferences are insights that are not readily apparent from the summary statistics but can be revealed through further analysis. We can use histograms,sub plots,scatter plots and heatmaps to visualize the data distribution and identify patterns.**

# %% [markdown]
# ## **Histogram**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()
data.hist(figsize=(10,10), color='blue')
plt.show()

# %% [markdown]
# ## **Sub Plot**

# %%
fig, axs = plt.subplots(ncols=5,nrows=3, figsize=(15, 10))
sns.kdeplot(data, x='fixed acidity', ax=axs[0,0])
sns.kdeplot(data, x='volatile acidity', ax=axs[0, 1])
sns.kdeplot(data, x='citric acid', ax=axs[0,2])
sns.kdeplot(data, x='residual sugar', ax=axs[0,3])
sns.kdeplot(data, x='chlorides', ax=axs[0,4])
sns.kdeplot(data, x='free sulfur dioxide', ax=axs[1,0])
sns.kdeplot(data, x='total sulfur dioxide', ax=axs[1, 1])
sns.kdeplot(data, x='density', ax=axs[1,2])
sns.kdeplot(data, x='pH', ax=axs[1,3])
sns.kdeplot(data, x='sulphates', ax=axs[1,4])
sns.kdeplot(data, x='alcohol', ax=axs[2, 0])
sns.kdeplot(data, x='quality', ax=axs[2, 1])
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %% [markdown]
# ## **Scatter Plot**

# %% [markdown]
# ### **They can be used to see correlations between two columns.**

# %%
plt.scatter(data['quality'], data['pH'], color='green')
plt.xlabel('quality')
plt.ylabel('pH')
plt.show()

# %% [markdown]
# ## **Heatmap**

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Between Columns')
plt.show()
